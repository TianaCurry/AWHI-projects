# %% [markdown]
# # Working with Geoplot
# ### Purpose:
#     - to create visulization of the data collections from different researchers
#     - interactive so people can learn about their researcher
#     - longterm goal: would like to have an interactive website
# - Geoplot pointplots:https://residentmario.github.io/geoplot/gallery/plot_usa_city_elevations.html
# - Georgaphical scatter plots plotly: https://plot.ly/python/scatter-plots-on-maps/
# - choropleth Maps in python: https://plot.ly/python/choropleth-maps/
# - examples of geo plots using plotly: https://www.bigendiandata.com/2017-06-27-Mapping_in_Jupyter/

# %%
import pandas as pd 
import numpy as np

# %%
rathbun_emu_df = pd.read_csv('AWHI_Rathbun_EMu.csv')
rathbun_emu_df.head()
# Out:
# /Users/curryt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ecatalogue_key       irn  CatBarcode DarCatalogNumber      DarClass  \
# 0               1     37327         NaN       6529.37327      Hydrozoa
# 1               2     17225         NaN      30987.17225     Scyphozoa
# 2               3  14276559         NaN      60791.14277  Malacostraca
# 3               4  13562270         NaN      49049.13562  Malacostraca
# 4               5  13562265         NaN      48516.13562  Malacostraca
#
#       DarCountry  DarDecimalLatitude  DarDecimalLongitude     DarFamily  \
# 0            NaN                 NaN                  NaN  Milleporidae
# 1            NaN                 NaN                  NaN     Ulmaridae
# ...

# %%
rathbun_emu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20561 entries, 0 to 20560
# Data columns (total 32 columns):
# ecatalogue_key                 20561 non-null int64
# irn                            20561 non-null int64
# CatBarcode                     0 non-null float64
# DarCatalogNumber               20561 non-null object
# DarClass                       20398 non-null object
# DarCountry                     19789 non-null object
# DarDecimalLatitude             15354 non-null float64
# DarDecimalLongitude            15350 non-null float64
# DarFamily                      20321 non-null object
# DarGenus                       20424 non-null object
# DarHigherTaxon                 20561 non-null object
# DarOrder                       20361 non-null object
# DarPhylum                      20561 non-null object
# DarScientificName              20424 non-null object
# DarScientificNameAuthor        20255 non-null object
# DarScientificNameAuthorYear    20255 non-null object
# ...
